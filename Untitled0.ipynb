# %% [markdown]
# <a href="https://colab.research.google.com/github/Rina-Pavluk/brave4075/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('sample_data/california_housing_test.csv')

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df.shape
# Out:
# (3000, 9)

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df[df['median_income'] < 2] [['median_house_value','median_income']]
# Out:
#       median_house_value  median_income
# 5                67000.0         1.6635
# 6                67000.0         1.6641
# 16              181300.0         1.8750
# 28              350000.0         1.5830
# 43               79300.0         0.9838
# ...                  ...            ...
# 2943             57200.0         1.6563
# 2964             91300.0         1.1434
# 2985            109400.0         1.8633
# 2986             85400.0         1.1346
# 2995            225000.0         1.1790
#
# [360 rows x 2 columns]

# %% [markdown]
# EMPTY MARKDOWN CELL, DOUBLE-CLICK OR PRESS ENTER TO EDIT

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
df[['longitude','latitude']]
# Out:
#       longitude  latitude
# 0       -122.05     37.37
# 1       -118.30     34.26
# 2       -117.81     33.78
# 3       -118.36     33.82
# 4       -119.67     36.33
# ...         ...       ...
# 2995    -119.86     34.42
# 2996    -118.14     34.06
# 2997    -119.70     36.30
# 2998    -117.12     34.10
# 2999    -119.63     34.42
#
# [3000 rows x 2 columns]

# %%
df.iloc[:,:2]
# Out:
#       longitude  latitude
# 0       -122.05     37.37
# 1       -118.30     34.26
# 2       -117.81     33.78
# 3       -118.36     33.82
# 4       -119.67     36.33
# ...         ...       ...
# 2995    -119.86     34.42
# 2996    -118.14     34.06
# 2997    -119.70     36.30
# 2998    -117.12     34.10
# 2999    -119.63     34.42
#
# [3000 rows x 2 columns]

# %% [markdown]
# Выбрать данные где housing_median_eight и median_house_value > 70000

# %%
df[(df['housing_median_age']< 20)&(df['median_house_value']> 70000)] [['housing_median_age','median_house_value']]
# Out:
#       housing_median_age  median_house_value
# 4                   19.0             81700.0
# 7                   19.0            166900.0
# 8                   15.0            194400.0
# 13                  16.0            231200.0
# 16                  15.0            181300.0
# ...                  ...                 ...
# 2978                17.0            139700.0
# 2981                17.0            171300.0
# 2984                13.0            107000.0
# 2985                17.0            109400.0
# 2991                13.0            253800.0
#
# [792 rows x 2 columns]

# %% [markdown]
# Определить какое максимальное и минимальное значение median_house_value

# %%
print(df['median_house_value'].max())
print(df['median_house_value'].min())
# Out:
# 500001.0
# 22500.0

# %%
df.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %% [markdown]
# Показать максимальное median_house_value где median_income = 3.1250

# %%
df[df['median_income'] == 3.1250] [['median_house_value','median_income']].max()
# Out:
# median_house_value    233300.000
# median_income              3.125
# dtype: float64

# %% [markdown]
# Узнать какая максимальная population в зоне минимального значения median_house_value

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df[df['median_house_value']==df['median_house_value'].min()] [['population', 'median_house_value']].max()
# Out:
# population             1230.0
# median_house_value    22500.0
# dtype: float64

# %% [markdown]
# Задача 40. работать с файлом California_housing_train.csv, который находится в папке sample_data. Определить среднюю стоимость дома, где кол-во людей от 0 до 500(population).

# %%
import pandas as pd
df = pd.read_csv('sample_data/california_housing_train.csv')

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df['population'].min()
# Out:
# 3.0

# %%
df[df['population']<500].median_house_value.mean()
# Out:
# 206683.83635227982

# %% [markdown]
# Задача 42. Узнать какая максимальная households в зоне минимального population

# %%
df[df['population']==df['population'].min()] [['population', 'households']].max()
# Out:
# population    3.0
# households    4.0
# dtype: float64

# %%
import pandas as pd
df = pd.read_csv('sample_data/california_housing_test.csv')

# %%
import seaborn as sns

# %% [markdown]
# 1.Изобразите отношение households  к population с помощью точечного графика

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
sns.scatterplot(data=df,y="households", x="population")
# Out:
# <Axes: xlabel='population', ylabel='households'>

# %% [markdown]
# Визуализировать longitude по отношению к median_house_value, используя линейный график

# %%
sns.relplot(x="longitude", y="median_house_value", kind="line", data=df)

# %% [markdown]
# Представить гистограмму по housing_median_age

# %%
sns.histplot(data=df, x="housing_median_age")
# Out:
# <Axes: xlabel='housing_median_age', ylabel='Count'>

# %% [markdown]
# Изобразить гистограму по median_house_value с оттенком housing_median_age

# %%
sns.histplot(data=df, x="median_house_value", hue="housing_median_age")
# Out:
# <Axes: xlabel='median_house_value', ylabel='Count'>

# %%
def move_legend(ax, new_loc, **kws):
    old_legend = ax.legend_
    handles = old_legend.legendHandles
    labels = [t.get_text() for t in old_legend.get_texts()]
    title = old_legend.get_title().get_text()
    ax.legend(handles, labels, loc=new_loc, title=title, bbox_to_anchor=(1,1), **kws)

fig, ax = plt.subplots()
sns.histplot(data=df, x='median_house_value', hue='housing_median_age', ax=ax)
move_legend(ax, "upper left")
# Out:
# <ipython-input-9-99e8efc3f047>:3: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   handles = old_legend.legendHandles

# %% [markdown]
# Использовать 2-3 точечных графика

# %%
sns.scatterplot(data=penguins,x="body_mass_g", y="sex")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='sex'>

# %%
sns.scatterplot(data=penguins,x="bill_length_mm", y="body_mass_g", size="sex")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='body_mass_g'>

# %%
sns.scatterplot(data=penguins,x="bill_length_mm", y="sex")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='sex'>

# %% [markdown]
# Применить доп измерение в точечных графиках, используя аргументы hue, size, style

# %%
sns.scatterplot(data=penguins,x="bill_length_mm", y="sex", hue="body_mass_g")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='sex'>

# %%
sns.scatterplot(data=penguins,x="bill_length_mm", y="sex", size="body_mass_g")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='sex'>

# %%
sns.scatterplot(data=penguins,x="bill_length_mm", y="body_mass_g", style="sex",hue="sex")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='body_mass_g'>

# %% [markdown]
# Использовать PairGrid  с типом графика на ваш выбор

# %%
cols=['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm']
g = sns.PairGrid(penguins[cols])
g.map(sns.scatterplot)

# %% [markdown]
# изобразить Heatmap

# %%
corr = penguins.corr()
sns.heatmap(corr,cmap='magma')
# Out:
# <ipython-input-26-f1005b6aacd6>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = penguins.corr()
# <Axes: >

# %%
corr = penguins.corr()
mask=np.triu(np.ones_like(corr,dtype=bool))

# Создаем полотно для отображения большого графика
f,ax=plt.subplots(figsize=(11,9))

# Создаем цветовую политру
cmap=sns.diverging_palette(66,20,as_cmap=True)

# Визуализируем данные кореляции
sns.heatmap(corr,mask=mask,cmap=cmap,vmax=.3,center=0,
square=True,linewidths=.5,cbar_kws={"shrink":.5})
# Out:
# <ipython-input-38-ecd44f04d2cb>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = penguins.corr()
# <Axes: >

# %%
penguins = sns.load_dataset("penguins")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# Использоват 2-3 Гистограммы

# %%
sns.histplot(data=penguins, x="body_mass_g")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %% [markdown]
# multiple{“layer”, “dodge”, “stack”, “fill”}multiple{“layer”, “dodge”, “stack”, “fill”}

# %%
sns.histplot(data=penguins, x="body_mass_g", hue="sex", multiple='dodge')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
sns.histplot(data=penguins, x="body_mass_g", hue="sex")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
sns.histplot(data=penguins, x="body_mass_g", hue="sex", multiple="stack")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %% [markdown]
# Создать новый столбец в таблице с пингвинами, который будет отвечать за показатель длины клюва пингвина. hidgh - длинный(от 42), middle - средний(от 35 до 42), low - маленький(до 35)

# %%
penguins['bill_res']= pd.Series(['high' if i >= 42 else 'middle' if 35< i < 42 else 'low' for i in penguins['bill_length_mm']])

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex bill_res
# 0       3750.0    Male   middle
# 1       3800.0  Female   middle
# 2       3250.0  Female   middle
# 3          NaN     NaN      low
# 4       3450.0  Female   middle

# %%
penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# изобразите гистограмму по flipper_length_mm с оттенком height_group. Сделать анализ

# %%
sns.histplot(data=penguins, x="flipper_length_mm", hue = "bill_res", multiple="dodge")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %% [markdown]
# Задача 44: В ячейке ниже представлен код генерирующий DataFrame, которая состоит всего из 1 столбца. Ваша задача перевести его в one hot вид. Сможете ли вы это сделать без get_dummies?

# %%
import random
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.head()
# Out:
#   whoAmI
# 0  human
# 1  robot
# 2  human
# 3  robot
# 4  robot

# %%
unique_values=data['whoAmI'].unique()
one_hot_data=pd.DataFrame()
for value in unique_values:
  one_hot_data[value]=(data['whoAmI']==value).astype(int)
one_hot_data.head()
# Out:
#    human  robot
# 0      1      0
# 1      0      1
# 2      1      0
# 3      0      1
# 4      0      1
